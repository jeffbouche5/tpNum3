# %% [markdown]
# #### Université Paul Sabatier  2025-2026
# # Simulations stochastiques - TP2

# %%
# %matplotlib inline
from matplotlib.pyplot import *
from math import *
from numpy import *
from numpy.random import *
from scipy.misc import *
from scipy.stats import *
#from scipy import *

# %% [markdown]
# ## Question 1:
# Soit $X$ une variable aléatoire de densité
# $$f(x) = \alpha \sin(x)\times \mathbb{1}_{]0,\pi[}(x),$$
# où $\alpha$ est un réel que l'on déterminera.
#
# Donner deux codes permettant de simuler un grand échantillon de $X$, puis tracer les histogrammes
# pour comparer avec la loi de densité $f$.
#
# *Indication : Les fonctions trignométriques réciproques sont accessibles en python via les commandes : <code>acos</code>,  <code>asin</code> et  <code>atan</code>.

# %% [markdown]
# ## Question 2: loi du demi-cercle
# Soit $X$ une variable aléatoire de densité
# $$f(x) = \frac{2}{\pi}\sqrt{1-x^2} \mathbb{1}_{[-1,1]}(x).$$
#
# Donner le code par la méthode du rejet qui vous permet de simuler un grand échantillon de $X$, puis tracer les histogrammes
# pour comparer avec la loi de densité $f$.

# %% [markdown]
# ## Question 3: loi uniforme sur le disque
# En utilisant la méthode du rejet, simuler 1000 variables aléatoires dans $\mathbb{R}^2$, uniformes sur le disque unité. Représenter ces réalisations pour vérifier qu'elles sont bien dans le disque unité.

# %% [markdown]
# ## Question 4: Simulation de loi de Poisson par les produits d’uniformes.
#
# Dans le TD 1, on vérifie que, si les $(U_i)_i$ sont i.i.d. uniformes sur $]0,1[$
# et $Z_k = U_1 \, U_2 \, \dots U_k$, alors la v.a. $K = \inf \{ k \geq 1 : Z_k \leq e^{-5} \} -1$
# suit une loi de Poisson de paramètre $5$.
#
# On rappelle que $K$ est caractérisée par
# $\prod_{j=1}^{K+1} U_j \leq e^{-5}  < \prod_{j=1}^{K} U_j$. Ecrire un code permettant de simuler
# un échantillon de taille $n$ (grand) de la loi de $K$. Et comparer l'histogramme associé
# à la loi de Poisson.

# %% [markdown]
# ## Simulation d'une Gaussienne via une Cauchy par rejet.
#
# On cherche ici à simuler une loi gaussienne $\mathcal{N}(0,1)$ à l'aide d'une loi de Cauchy
# de densité $g(x)= \frac{1}{\pi (1+x^2)} $ par rapport à la mesure de Lebesgue sur $\mathbb{R}$.

# %% [markdown]
# ## Question 5
#
# Ecrire une fonction 'simucauchy' permettant de simuler un $N$-échantillon de
# loi de Cauchy, à l'aide de la méthode d'inversion de la fonction de répartition. Illustrer votre code
# à l'aide d'un histogramme et en comparant à la densité $g$.
#
# Pour vous aider, même si le calcul est très simple,
# on donne $F(t)= \frac{1}{\pi} \arctan t + \frac{1}{2}$. C'est une bijection continue de $\mathbb{R}$ sur $]0,1[$.
# L'inverse généralisé coïncide donc avec la réciproque : pour tout $t \in \mathbb{R}$ et $u \in ]0,1[$,
# $$
# u= F(t) \Leftrightarrow t = F^{-1}(u).
# $$

# %%
   
def simucauchy(N):

...

# %%
N=10**4
...

# histogramme et comparaison à g

...

# %% [markdown]
# ## Question 6
#
# Utiliser la question précédente pour simuler un échantillon gaussien centré réduit de taille $N= 10000$,
# par la méthode du rejet. Vérifier votre résultat à l'aide d'un histogramme, en comparant à la densité de la gaussienne. On pourra utiliser (sans preuve)
# que la fonction $x \in \mathbb{R} \mapsto (1+x^2) e^{-\frac{x^2}{2}}$ admet la valeur $2 e^{-1/2}$ comme maximum.

# %%
N= 10**4

...

# %%
# histogramme et comparaison à la densité gaussienne

...
